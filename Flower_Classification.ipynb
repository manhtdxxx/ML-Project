# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import tensorflow as tf
from tensorflow import keras
import os
from PIL import Image
import cv2
import pathlib

# %% [markdown]
# # Import Dataset

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

data_dir = keras.utils.get_file(fname='flower_dataset',
                                origin=dataset_url,
                                cache_dir = '.',
                                untar=True
                                )

# %%
type(data_dir), data_dir
# Out:
# (str, './datasets/flower_dataset')

# %%
flower_dir = pathlib.Path(data_dir + '/flower_photos')
type(flower_dir), flower_dir
# When you convert data_dir to a pathlib.Path object,
# you gain the flexibility and power of the pathlib module to work with the file system
# Out:
# (pathlib.PosixPath, PosixPath('datasets/flower_dataset/flower_photos'))

# %% [markdown]
# #  Data Exploration

# %%
flower_dir.glob('*/*.jpg')  # an object of paths of all images in each sub-dir
# Out:
# <generator object Path.glob at 0x7a5f2181bde0>

# %%
flower_paths = list(flower_dir.glob('*/*.jpg')) # turns an object into a list containing paths
flower_paths[:5]
# Out:
# [PosixPath('datasets/flower_dataset/flower_photos/tulips/14073608876_49db8ac97d_n.jpg'),
#  PosixPath('datasets/flower_dataset/flower_photos/tulips/16680998737_6f6225fe36.jpg'),
#  PosixPath('datasets/flower_dataset/flower_photos/tulips/14487705209_ea723109e1_m.jpg'),
#  PosixPath('datasets/flower_dataset/flower_photos/tulips/13999402743_f563f6b685_n.jpg'),
#  PosixPath('datasets/flower_dataset/flower_photos/tulips/13510057763_01b832d919.jpg')]

# %%
flower_paths = {
    'roses': list(flower_dir.glob('roses/*.jpg')),
    'daisy': list(flower_dir.glob('daisy/*.jpg')),
    'dandelion': list(flower_dir.glob('dandelion/*.jpg')),
    'sunflowers': list(flower_dir.glob('sunflowers/*.jpg')),
    'tulips': list(flower_dir.glob('tulips/*.jpg')),
}

# %%
for i in flower_paths.keys():
    print('{:<11}: {}'.format(i, len(flower_paths[i])))
# Out:
# roses      : 641
# daisy      : 633
# dandelion  : 898
# sunflowers : 699
# tulips     : 799

# %%
im = Image.open(str(flower_paths['roses'][2]))  # converts type from WindowsPath to str
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
im.resize(size=(180, 180))
# Out:
# <PIL.Image.Image image mode=RGB size=180x180>

# %%
for i in flower_paths.keys():
    for j in range(2):
        print(cv2.imread(str(flower_paths[i][j])).shape)  # images have different shapes
# Out:
# (240, 225, 3)
# (328, 500, 3)
# (240, 320, 3)
# (208, 320, 3)
# (223, 240, 3)
# (256, 320, 3)
# (213, 320, 3)
# (333, 500, 3)
# (213, 320, 3)
# (333, 500, 3)

# %% [markdown]
# # Data Preprocessing

# %%
labels = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
X = []  # contains arrays
Y = []  # contains label for each flower

for flower_type, paths in flower_paths.items():
    for path in paths:
        arr = cv2.imread(str(path))
        resized_arr = cv2.resize(arr, (180, 180))
        X.append(resized_arr)
        Y.append(labels[flower_type])

# %%
X = np.array(X)
Y = np.array(Y)
X.shape, Y.shape
# Out:
# ((3670, 180, 180, 3), (3670,))

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, stratify=Y)  # split dataset to train and test set

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, stratify=Y_train) # split train set to train set and validation set

Y_train.shape, Y_val.shape, Y_test.shape
# Out:
# ((2972,), (331,), (367,))

# %%
np.unique(Y_train, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([519, 513, 727, 566, 647]))

# %% [markdown]
# - The class is just slightly imbalanced for training set but I think that's okay

# %%
np.unique(Y_val, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([58, 57, 81, 63, 72]))

# %%
np.unique(Y_test, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([64, 63, 90, 70, 80]))

# %%
X_train_scaled = X_train / 255
X_val_scaled = X_val / 255
X_test_scaled = X_test / 255

# %% [markdown]
# # Training

# %% [markdown]
# ### Without Augmentation

# %%
Model_without_Augmenter = keras.Sequential([
    # CNN
    keras.layers.Input(shape=(180, 180, 3)),
    keras.layers.Conv2D(filters=18, kernel_size=(3,3), padding='same', activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
    keras.layers.Conv2D(filters=36, kernel_size=(3,3), padding='same', activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
    keras.layers.Conv2D(filters=72, kernel_size=(3,3), padding='same', activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
    # NN
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(5, activation='softmax')
])

Model_without_Augmenter.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 180, 180, 18)        │             504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 18)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 36)          │           5,868 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 36)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 72)          │          23,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 72)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 34848)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       4,460,672 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,491,089 (17.13 MB)
#  Trainable params: 4,491,089 (17.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
Model_without_Augmenter.compile(
    optimizer='adam',
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
    )

Model_without_Augmenter.fit(X_train_scaled, Y_train, batch_size=64, epochs=40, validation_data=(X_val_scaled, Y_val))
# Out:
# Epoch 1/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 14s 164ms/step - accuracy: 0.3361 - loss: 1.5663 - val_accuracy: 0.5710 - val_loss: 1.0660
# Epoch 2/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.5572 - loss: 1.1225 - val_accuracy: 0.6284 - val_loss: 0.9794
# Epoch 3/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6319 - loss: 0.9746 - val_accuracy: 0.5619 - val_loss: 1.0940
# Epoch 4/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.6856 - loss: 0.8097 - val_accuracy: 0.6254 - val_loss: 0.9834
# Epoch 5/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.7627 - loss: 0.6350 - val_accuracy: 0.6344 - val_loss: 0.9704
# Epoch 6/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.8400 - loss: 0.4595 - val_accuracy: 0.6193 - val_loss: 1.1688
# Epoch 7/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8972 - loss: 0.3062 - val_accuracy: 0.6254 - val_loss: 1.2785
# Epoch 8/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9369 - loss: 0.2080 - val_accuracy: 0.6435 - val_loss: 1.4536
# Epoch 9/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9615 - loss: 0.1327 - val_accuracy: 0.6314 - val_loss: 1.5655
# Epoch 10/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9734 - loss: 0.0911 - val_accuracy: 0.6375 - val_loss: 1.7452
# Epoch 11/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9770 - loss: 0.0760 - val_accuracy: 0.6314 - val_loss: 1.7501
# Epoch 12/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9821 - loss: 0.0627 - val_accuracy: 0.6133 - val_loss: 1.9715
# Epoch 13/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9845 - loss: 0.0490 - val_accuracy: 0.6224 - val_loss: 2.0410
# Epoch 14/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9911 - loss: 0.0433 - val_accuracy: 0.6103 - val_loss: 2.1726
# Epoch 15/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9930 - loss: 0.0247 - val_accuracy: 0.6012 - val_loss: 2.2620
# Epoch 16/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9894 - loss: 0.0414 - val_accuracy: 0.6254 - val_loss: 2.2155
# Epoch 17/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9907 - loss: 0.0327 - val_accuracy: 0.6042 - val_loss: 2.2907
# Epoch 18/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9907 - loss: 0.0429 - val_accuracy: 0.6042 - val_loss: 2.3192
# Epoch 19/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9929 - loss: 0.0268 - val_accuracy: 0.6284 - val_loss: 2.4368
# Epoch 20/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9929 - loss: 0.0286 - val_accuracy: 0.6556 - val_loss: 2.6176
# Epoch 21/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9924 - loss: 0.0245 - val_accuracy: 0.6405 - val_loss: 2.6934
# Epoch 22/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9935 - loss: 0.0176 - val_accuracy: 0.6405 - val_loss: 2.4018
# Epoch 23/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9974 - loss: 0.0160 - val_accuracy: 0.6224 - val_loss: 2.7052
# Epoch 24/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9949 - loss: 0.0134 - val_accuracy: 0.6073 - val_loss: 2.7367
# Epoch 25/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9889 - loss: 0.0325 - val_accuracy: 0.6133 - val_loss: 2.6144
# Epoch 26/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9958 - loss: 0.0146 - val_accuracy: 0.6375 - val_loss: 2.6095
# Epoch 27/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9945 - loss: 0.0188 - val_accuracy: 0.6224 - val_loss: 2.7865
# Epoch 28/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9977 - loss: 0.0098 - val_accuracy: 0.6405 - val_loss: 3.0309
# Epoch 29/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9942 - loss: 0.0125 - val_accuracy: 0.6254 - val_loss: 2.7343
# Epoch 30/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9964 - loss: 0.0102 - val_accuracy: 0.6314 - val_loss: 2.9924
# Epoch 31/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9923 - loss: 0.0179 - val_accuracy: 0.6314 - val_loss: 2.8927
# Epoch 32/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9961 - loss: 0.0098 - val_accuracy: 0.6405 - val_loss: 2.9060
# Epoch 33/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9925 - loss: 0.0222 - val_accuracy: 0.6314 - val_loss: 2.9313
# Epoch 34/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9884 - loss: 0.0351 - val_accuracy: 0.6224 - val_loss: 2.8228
# Epoch 35/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9913 - loss: 0.0189 - val_accuracy: 0.6556 - val_loss: 2.9898
# Epoch 36/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9974 - loss: 0.0088 - val_accuracy: 0.6405 - val_loss: 3.0207
# Epoch 37/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9944 - loss: 0.0126 - val_accuracy: 0.6495 - val_loss: 2.9535
# Epoch 38/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9972 - loss: 0.0102 - val_accuracy: 0.6103 - val_loss: 3.0078
# Epoch 39/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9967 - loss: 0.0118 - val_accuracy: 0.6284 - val_loss: 2.9811
# Epoch 40/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9968 - loss: 0.0122 - val_accuracy: 0.6405 - val_loss: 3.2240

# %%
Model_without_Augmenter.evaluate(X_test_scaled, Y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6444 - loss: 2.5305
# [2.791633367538452, 0.6376021504402161]

# %% [markdown]
# The accuracy of training set is very high compared to the accuracy of validation set and test set --> Model is OVERFITTING!!!

# %%
prob_1 = Model_without_Augmenter.predict(X_test_scaled)
Yp_test_1 = np.array([np.argmax(i) for i in prob_1])
Yp_test_1.shape
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# (367,)

# %%
cr_1 = classification_report(Y_test, Yp_test_1)

# %%
cm_1 = confusion_matrix(Y_test, Yp_test_1)
display_cm1 = ConfusionMatrixDisplay(cm_1, display_labels=list(labels.keys()))

# %% [markdown]
# ### Using Augmentation

# %% [markdown]
# https://keras.io/api/layers/preprocessing_layers

# %%
augmenter = keras.Sequential()
augmenter.add(keras.layers.RandomZoom(height_factor=(-0.25, 0.25), width_factor=(-0.25, 0.25)))
augmenter.add(keras.layers.RandomFlip(mode='horizontal'))
augmenter.add(keras.layers.RandomRotation(factor=(-0.25, 0.25)))
augmenter.add(keras.layers.RandomContrast(factor=0.25))

# %%
augmented_tensor = augmenter(X_train_scaled[:30])
augmented_tensor.shape
# Out:
# TensorShape([30, 180, 180, 3])

# %%
augmented_arr = np.array(augmented_tensor[0])
augmented_arr.dtype
# Out:
# dtype('float32')

# %%
def clip_image(image):
    if image.dtype == np.float32 or image.dtype == np.float64:
        return np.clip(image, 0.0, 1.0)

# %%
fig, subs = plt.subplots(ncols=8, nrows=4, figsize=(12, 6))

images = []
for i in range(16):
    images.append(X_train_scaled[i+5])
    images.append(augmented_tensor[i+5])

for ax, img in zip(subs.flatten(), images):
    ax.matshow(clip_image(img))
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
Model_with_Augmenter = keras.Sequential([
    keras.layers.Input(shape=(180, 180, 3)),
    # Augment Layers
    augmenter,
    # CNN
    keras.layers.Conv2D(filters=18, kernel_size=(3,3), padding='same', activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
    keras.layers.Conv2D(filters=36, kernel_size=(3,3), padding='same', activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
    keras.layers.Conv2D(filters=72, kernel_size=(3,3), padding='same', activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)),
    # NN
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(5, activation='softmax')
])

Model_with_Augmenter.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 180, 180, 18)        │             504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 90, 90, 18)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 90, 90, 36)          │           5,868 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 45, 45, 36)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 45, 45, 72)          │          23,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 22, 22, 72)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 34848)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       4,460,672 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,491,089 (17.13 MB)
#  Trainable params: 4,491,089 (17.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
Model_with_Augmenter.compile(
    optimizer='adam',
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
    )

Model_with_Augmenter.fit(X_train_scaled, Y_train, batch_size=64, epochs=35, validation_data=(X_val_scaled, Y_val))
# Out:
# Epoch 1/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.3330 - loss: 1.4881 - val_accuracy: 0.4985 - val_loss: 1.1669
# Epoch 2/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.5108 - loss: 1.1639 - val_accuracy: 0.6073 - val_loss: 1.0433
# Epoch 3/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.5854 - loss: 1.0279 - val_accuracy: 0.6405 - val_loss: 0.9472
# Epoch 4/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6224 - loss: 0.9588 - val_accuracy: 0.6314 - val_loss: 0.9243
# Epoch 5/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6325 - loss: 0.9303 - val_accuracy: 0.6828 - val_loss: 0.8510
# Epoch 6/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6820 - loss: 0.8499 - val_accuracy: 0.6586 - val_loss: 0.8638
# Epoch 7/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.6822 - loss: 0.8371 - val_accuracy: 0.6949 - val_loss: 0.8067
# Epoch 8/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.6597 - loss: 0.8391 - val_accuracy: 0.6798 - val_loss: 0.7911
# Epoch 9/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.7016 - loss: 0.8024 - val_accuracy: 0.7100 - val_loss: 0.7916
# Epoch 10/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.6987 - loss: 0.7759 - val_accuracy: 0.6858 - val_loss: 0.7908
# Epoch 11/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.7028 - loss: 0.7516 - val_accuracy: 0.6828 - val_loss: 0.7765
# Epoch 12/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.7244 - loss: 0.7265 - val_accuracy: 0.7130 - val_loss: 0.7072
# Epoch 13/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.7440 - loss: 0.6709 - val_accuracy: 0.6918 - val_loss: 0.7475
# Epoch 14/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.7275 - loss: 0.6829 - val_accuracy: 0.7221 - val_loss: 0.6933
# Epoch 15/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.7293 - loss: 0.6730 - val_accuracy: 0.7190 - val_loss: 0.7039
# Epoch 16/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.7455 - loss: 0.6776 - val_accuracy: 0.7160 - val_loss: 0.7346
# Epoch 17/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.7487 - loss: 0.6516 - val_accuracy: 0.7402 - val_loss: 0.6953
# Epoch 18/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.7685 - loss: 0.6091 - val_accuracy: 0.7583 - val_loss: 0.6736
# Epoch 19/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.7348 - loss: 0.6526 - val_accuracy: 0.7674 - val_loss: 0.6564
# Epoch 20/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.7621 - loss: 0.6242 - val_accuracy: 0.7069 - val_loss: 0.6864
# Epoch 21/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.7595 - loss: 0.6121 - val_accuracy: 0.7825 - val_loss: 0.6364
# Epoch 22/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.7718 - loss: 0.5770 - val_accuracy: 0.7613 - val_loss: 0.6675
# Epoch 23/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.7816 - loss: 0.5746 - val_accuracy: 0.7492 - val_loss: 0.6341
# Epoch 24/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.7885 - loss: 0.5609 - val_accuracy: 0.7553 - val_loss: 0.6560
# Epoch 25/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.7879 - loss: 0.5479 - val_accuracy: 0.7613 - val_loss: 0.6286
# Epoch 26/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.7883 - loss: 0.5537 - val_accuracy: 0.7553 - val_loss: 0.6711
# Epoch 27/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8074 - loss: 0.5091 - val_accuracy: 0.7613 - val_loss: 0.6783
# Epoch 28/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8095 - loss: 0.4957 - val_accuracy: 0.7583 - val_loss: 0.6427
# Epoch 29/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.7997 - loss: 0.5117 - val_accuracy: 0.7311 - val_loss: 0.6904
# Epoch 30/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.8039 - loss: 0.5120 - val_accuracy: 0.7372 - val_loss: 0.6558
# Epoch 31/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8207 - loss: 0.4687 - val_accuracy: 0.7341 - val_loss: 0.6995
# Epoch 32/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8072 - loss: 0.4824 - val_accuracy: 0.7553 - val_loss: 0.6372
# Epoch 33/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.8074 - loss: 0.4864 - val_accuracy: 0.7734 - val_loss: 0.6302
# Epoch 34/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8149 - loss: 0.4743 - val_accuracy: 0.7221 - val_loss: 0.7169
# Epoch 35/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8062 - loss: 0.4877 - val_accuracy: 0.7553 - val_loss: 0.6533

# %% [markdown]
# - Over 35 epochs, I didnt see any major improvements on `val_accuracy`

# %%
Model_with_Augmenter.evaluate(X_test_scaled, Y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7847 - loss: 0.6739
# [0.6104063391685486, 0.7929155230522156]

# %%
prob_2 = Model_with_Augmenter.predict(X_test_scaled)
Yp_test_2 = np.array([np.argmax(i) for i in prob_2])
Yp_test_2.shape
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# (367,)

# %%
cr_2 = classification_report(Y_test, Yp_test_2)

# %%
cm_2 = confusion_matrix(Y_test, Yp_test_2)
display_cm2 = ConfusionMatrixDisplay(cm_2, display_labels=list(labels.keys()))

# %% [markdown]
# # Compare

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

display_cm2.plot(ax=axes[0])
axes[0].set_xlabel('Predicted label', fontsize=16, labelpad=10)
axes[0].set_ylabel('True label', fontsize=16, labelpad=10)
axes[0].set_title('Confusion Matrix using Augmenter', fontsize=18)

display_cm1.plot(ax=axes[1])
axes[1].set_xlabel('Predicted label', fontsize=16, labelpad=10)
axes[1].set_ylabel('True label', fontsize=16, labelpad=10)
axes[1].set_title('Confusion Matrix without Augmenter', fontsize=18)

plt.tight_layout()
plt.show()

# %% [markdown]
# - The left confusion matrix (with augmentation) shows better classification performance.
# - The right confusion matrix (without augmentation) has more misclassifications, particularly for classes like roses and tulips, where more predictions are spread across incorrect classes.
# - With augmentation, the classifier correctly predicts more instances per class, leading to a higher diagonal dominance (correct classifications).

# %%
print(cr_2)
print('-'*100)
print(cr_1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.81      0.72        64
#            1       0.84      0.76      0.80        63
#            2       0.86      0.88      0.87        90
#            3       0.83      0.84      0.84        70
#            4       0.80      0.66      0.73        80
#
#     accuracy                           0.79       367
#    macro avg       0.80      0.79      0.79       367
# weighted avg       0.80      0.79      0.79       367
#
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.58      0.47      0.52        64
#            1       0.69      0.59      0.63        63
#            2       0.66      0.79      0.72        90
#            3       0.69      0.79      0.73        70
#            4       0.55      0.51      0.53        80
#
#     accuracy                           0.64       367
#    macro avg       0.63      0.63      0.63       367
# weighted avg       0.63      0.64      0.63       367

# %% [markdown]
# - The first classification report shows better performance metrics (precision, recall, F1-score) across all classes.
# - The accuracy in the first report is 79%, while in the second report, it drops to 64%.
# - The macro and weighted averages are also significantly higher in the first case.
